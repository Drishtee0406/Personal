# %%
import pandas as pd
from itertools import combinations

# %%
file_path = "accidents.csv"

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    RushHour  WRK_ZONE  WKDY  INT_HWY  LGTCON_day  LEVEL  SPD_LIM  \
# 0         1         0     1        1           0      1       70
# 1         1         0     1        0           0      0       55
# 2         1         0     0        0           0      0       35
# 3         1         0     1        0           0      1       35
# 4         1         0     1        0           0      0       25
#
#    SUR_COND_dry  TRAF_two_way  WEATHER_adverse    MAX_SEV
# 0             0             0                1  no-injury
# 1             0             1                0  non-fatal
# 2             0             0                1  no-injury
# 3             0             0                1  no-injury
# 4             0             0                1  non-fatal

# %%
df.tail()
# Out:
#      RushHour  WRK_ZONE  WKDY  INT_HWY  LGTCON_day  LEVEL  SPD_LIM  \
# 595         0         0     1        0           1      0       55
# 596         1         0     0        0           1      0       55
# 597         0         0     1        0           1      0       55
# 598         0         0     0        0           1      0       65
# 599         0         0     0        0           1      0       70
#
#      SUR_COND_dry  TRAF_two_way  WEATHER_adverse    MAX_SEV
# 595             1             1                0  no-injury
# 596             1             1                0  no-injury
# 597             1             1                0  no-injury
# 598             1             1                0  non-fatal
# 599             1             1                0  no-injury

# %%
df.head(30)
# Out:
#     RushHour  WRK_ZONE  WKDY  INT_HWY  LGTCON_day  LEVEL  SPD_LIM  \
# 0          1         0     1        1           0      1       70
# 1          1         0     1        0           0      0       55
# 2          1         0     0        0           0      0       35
# 3          1         0     1        0           0      1       35
# 4          1         0     1        0           0      0       25
# 5          1         0     1        0           0      0       35
# 6          1         0     1        0           0      0       60
# 7          1         0     1        0           0      1       45
# 8          0         0     1        1           0      0       55
# 9          1         0     1        1           0      0       70
# 10         0         0     1        1           0      0       65
# 11         1         0     1        0           0      0       40
# 12         1         0     1        0           0      0       45
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RushHour         600 non-null    int64
#  1   WRK_ZONE         600 non-null    int64
#  2   WKDY             600 non-null    int64
#  3   INT_HWY          600 non-null    int64
#  4   LGTCON_day       600 non-null    int64
#  5   LEVEL            600 non-null    int64
#  6   SPD_LIM          600 non-null    int64
#  7   SUR_COND_dry     600 non-null    int64
#  8   TRAF_two_way     600 non-null    int64
#  9   WEATHER_adverse  600 non-null    int64
#  10  MAX_SEV          600 non-null    object
# dtypes: int64(10), object(1)
# memory usage: 51.7+ KB

# %%
df.describe()
# Out:
#          RushHour    WRK_ZONE        WKDY     INT_HWY  LGTCON_day       LEVEL  \
# count  600.000000  600.000000  600.000000  600.000000   600.00000  600.000000
# mean     0.458333    0.011667    0.795000    0.146667     0.73000    0.230000
# std      0.498677    0.107470    0.404038    0.495545     0.44433    0.421184
# min      0.000000    0.000000    0.000000    0.000000     0.00000    0.000000
# 25%      0.000000    0.000000    1.000000    0.000000     0.00000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000     1.00000    0.000000
# 75%      1.000000    0.000000    1.000000    0.000000     1.00000    0.000000
# max      1.000000    1.000000    1.000000    9.000000     1.00000    1.000000
#
#           SPD_LIM  SUR_COND_dry  TRAF_two_way  WEATHER_adverse
# count  600.000000    600.000000    600.000000       600.000000
# mean    43.291667      0.785000      0.583333         0.161667
# std     12.269508      0.411165      0.493418         0.368452
# ...

# %%
df['MAX_SEV']
# Out:
# 0      no-injury
# 1      non-fatal
# 2      no-injury
# 3      no-injury
# 4      non-fatal
#          ...
# 595    no-injury
# 596    no-injury
# 597    no-injury
# 598    non-fatal
# 599    no-injury
# Name: MAX_SEV, Length: 600, dtype: object

# %%
df['WKDY']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 595    1
# 596    0
# 597    1
# 598    0
# 599    0
# Name: WKDY, Length: 600, dtype: int64

# %%
df['LEVEL'].head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: LEVEL, dtype: int64

# %%
LIST_OF_COLS =['RushHour', 'MAX_SEV']
df[LIST_OF_COLS]
# Out:
#      RushHour    MAX_SEV
# 0           1  no-injury
# 1           1  non-fatal
# 2           1  no-injury
# 3           1  no-injury
# 4           1  non-fatal
# ..        ...        ...
# 595         0  no-injury
# 596         1  no-injury
# 597         0  no-injury
# 598         0  non-fatal
# 599         0  no-injury
#
# [600 rows x 2 columns]

# %%
df.iloc[3]
# Out:
# RushHour                   1
# WRK_ZONE                   0
# WKDY                       1
# INT_HWY                    0
# LGTCON_day                 0
# LEVEL                      1
# SPD_LIM                   35
# SUR_COND_dry               0
# TRAF_two_way               0
# WEATHER_adverse            1
# MAX_SEV            no-injury
# Name: 3, dtype: object

# %%
df.iloc[0 : 5]
# Out:
#    RushHour  WRK_ZONE  WKDY  INT_HWY  LGTCON_day  LEVEL  SPD_LIM  \
# 0         1         0     1        1           0      1       70
# 1         1         0     1        0           0      0       55
# 2         1         0     0        0           0      0       35
# 3         1         0     1        0           0      1       35
# 4         1         0     1        0           0      0       25
#
#    SUR_COND_dry  TRAF_two_way  WEATHER_adverse    MAX_SEV
# 0             0             0                1  no-injury
# 1             0             1                0  non-fatal
# 2             0             0                1  no-injury
# 3             0             0                1  no-injury
# 4             0             0                1  non-fatal

# %%
df.iloc[0:3 , 3]
# Out:
# 0    1
# 1    0
# 2    0
# Name: INT_HWY, dtype: int64

# %%
df.loc[6:]
# Out:
#      RushHour  WRK_ZONE  WKDY  INT_HWY  LGTCON_day  LEVEL  SPD_LIM  \
# 6           1         0     1        0           0      0       60
# 7           1         0     1        0           0      1       45
# 8           0         0     1        1           0      0       55
# 9           1         0     1        1           0      0       70
# 10          0         0     1        1           0      0       65
# ..        ...       ...   ...      ...         ...    ...      ...
# 595         0         0     1        0           1      0       55
# 596         1         0     0        0           1      0       55
# 597         0         0     1        0           1      0       55
# 598         0         0     0        0           1      0       65
# 599         0         0     0        0           1      0       70
#
#      SUR_COND_dry  TRAF_two_way  WEATHER_adverse    MAX_SEV
# 6               0             0                0  no-injury
# ...

# %%
df.loc[5:, 'WEATHER_adverse']
# Out:
# 5      1
# 6      0
# 7      0
# 8      0
# 9      0
#       ..
# 595    0
# 596    0
# 597    0
# 598    0
# 599    0
# Name: WEATHER_adverse, Length: 595, dtype: int64

# %%
df['MAX_SEV'] =='non-fatal'
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 595    False
# 596    False
# 597    False
# 598     True
# 599    False
# Name: MAX_SEV, Length: 600, dtype: bool

# %%
df[df['MAX_SEV'] =='non-fatal']
# Out:
#      RushHour  WRK_ZONE  WKDY  INT_HWY  LGTCON_day  LEVEL  SPD_LIM  \
# 1           1         0     1        0           0      0       55
# 4           1         0     1        0           0      0       25
# 5           1         0     1        0           0      0       35
# 7           1         0     1        0           0      1       45
# 9           1         0     1        1           0      0       70
# ..        ...       ...   ...      ...         ...    ...      ...
# 585         0         0     0        0           1      0       45
# 586         0         0     0        0           1      0       45
# 593         0         0     0        0           1      0       55
# 594         1         0     1        0           1      0       55
# 598         0         0     0        0           1      0       65
#
#      SUR_COND_dry  TRAF_two_way  WEATHER_adverse    MAX_SEV
# 1               0             1                0  non-fatal
# ...
